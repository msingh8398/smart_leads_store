# %%
sample_res = {
  "AnalyzeDocumentModelVersion": "1.0",
  "Blocks": [
    {
      "BlockType": "PAGE",
      "Geometry": {
        "BoundingBox": {
          "Height": 1.0,
          "Left": 0.0,
          "Top": 0.0,
          "Width": 1.0
        },
        "Polygon": [
          {
            "X": 0.0,
            "Y": 3.970609157022409E-7
          },
          {
            "X": 1.0,
            "Y": 0.0
          },
          {
            "X": 1.0,
            "Y": 1.0
          },
          {
            "X": 7.421712098221178E-7,
            "Y": 1.0
          }
        ]
      },
      "Id": "208bf7c7-fbaf-47df-ad24-5a8a7b8261f7",
      "Relationships": [
        {
          "Ids": [
            "50d91fb5-fad2-4d0d-9056-5aa1365ee55f",
            "a367e25e-59df-4772-9f23-5e9399706843",
            "9a46862c-c794-489e-8a52-756db47d79af",
            "04d09292-fc71-49ff-b142-32a94e6afbf6",
            "2b1c13a9-98df-4247-8f40-09f5f0b2f7af",
            "4664008a-79c9-4a49-bdde-63d5d92febd2",
            "9952a7a8-7a5b-4f43-ab31-676bb9143e94",
            "0e75c450-7d7f-4f32-bea6-6bb39f9a5790",
            "d865002e-7c14-483d-a562-80f6507537e4",
            "82cd4db8-c54f-47cf-8d97-258aedc9e376",
            "e7f8857d-277c-45ee-8821-daf81f6ec9eb",
            "ec063eb9-52d7-47a6-960d-0a17679d0fd3",
            "f2b1779f-41d2-4b01-b527-15306a9e59d8"
          ],
          "Type": "CHILD"
        }
      ]
    },
    {
      "BlockType": "LINE",
      "Confidence": 91.37188720703125,
      "Geometry": {
        "BoundingBox": {
          "Height": 0.09335628896951675,
          "Left": 0.520653247833252,
          "Top": 0.20938247442245483,
          "Width": 0.27065518498420715
        },
        "Polygon": [
          {
            "X": 0.520653247833252,
            "Y": 0.2097129225730896
          },
          {
            "X": 0.791263997554779,
            "Y": 0.20938247442245483
          },
          {
            "X": 0.7913084626197815,
            "Y": 0.3024165630340576
          },
          {
            "X": 0.5206948518753052,
            "Y": 0.302738755941391
          }
        ]
      },
      "Id": "50d91fb5-fad2-4d0d-9056-5aa1365ee55f",
      "Relationships": [
        {
          "Ids": [
            "677c9b1b-40bb-45b0-b9db-336dba466820"
          ],
          "Type": "CHILD"
        }
      ],
      "Text": "packetvideo"
    },
    {
      "BlockType": "LINE",
      "Confidence": 99.85772705078125,
      "Geometry": {
        "BoundingBox": {
          "Height": 0.051549360156059265,
          "Left": 0.09310358762741089,
          "Top": 0.42751365900039673,
          "Width": 0.22966988384723663
        },
        "Polygon": [
          {
            "X": 0.09310358762741089,
            "Y": 0.4277776777744293
          },
          {
            "X": 0.3227517008781433,
            "Y": 0.42751365900039673
          },
          {
            "X": 0.3227734863758087,
            "Y": 0.478802889585495
          },
          {
            "X": 0.09312401711940765,
            "Y": 0.4790630340576172
          }
        ]
      },
      "Id": "a367e25e-59df-4772-9f23-5e9399706843",
      "Relationships": [
        {
          "Ids": [
            "84b72814-52bf-4e8c-992d-f410ee599760",
            "9ed4a9c7-d1bf-43ad-8e6e-5931b62a83e6"
          ],
          "Type": "CHILD"
        }
      ],
      "Text": "Richard Svienty"
    },
    {
      "BlockType": "LINE",
      "Confidence": 99.9298095703125,
      "Geometry": {
        "BoundingBox": {
          "Height": 0

    },
    {
      "BlockType": "LINE",
      "Confidence": 99.34839630126953,
      "Geometry": {
        "BoundingBox": {
          "Height": 0.049295250326395035,
          "Left": 0.40632563829421997,
          "Top": 0.6479007005691528,
          "Width": 0.40346795320510864
        },
        "Polygon": [
          {
            "X": 0.40632563829421997,
            "Y": 0.6483352184295654
          },
          {
            "X": 0.8097701668739319,
            "Y": 0.6479007005691528
          },
          {
            "X": 0.8097935914993286,
            "Y": 0.6967679262161255
          },
          {
            "X": 0.4063468277454376,
            "Y": 0.6971959471702576
          }
        ]
      },
      "Id": "9952a7a8-7a5b-4f43-ab31-676bb9143e94",
      "Relationships": [
        {
          "Ids": [
            "f0cdb575-9247-44d0-a6a8-493af9119788",
            "85e1176e-8991-459e-bd41-aec88a842869",
            "d3e4e845-da0c-4cc8-a346-49057e274597",
            "f0500e1d-e5c2-48f2-82fd-7c28f3e16dd5"
          ],
          "Type": "CHILD"
        }
      ],
      "Text": "hoffman estates, illinois 60192"
    },
    {
      "BlockType": "LINE",
      "Confidence": 99.28849792480469,
      "Geometry": {
        "BoundingBox": {
          "Height": 0.051345229148864746,
          "Left": 0.1019669622182846,
          "Top": 0.742109477519989,
          "Width": 0.22008559107780457
        },
        "Polygon": [
          {
            "X": 0.1019669622182846,
            "Y": 0.7423397302627563
          },
          {
            "X": 0.3220308721065521,
            "Y": 0.742109477519989
          },
          {
            "X": 0.32205256819725037,
            "Y": 0.7932281494140625
          },
          {
            "X": 0.10198737680912018,
            "Y": 0.7934547066688538
          }
        ]
      },
      "Id": "0e75c450-7d7f-4f32-bea6-6bb39f9a5790",
      "Relationships": [
        {
          "Ids": [
            "7b43f5ee-716b-4c74-a7d7-d6e4fe40a7aa"
          ],
          "Type": "CHILD"
        }
      ],
      "Text": "svienty@pv.com"
    },
    {
      "BlockType": "LINE",
      "Confidence": 99.37836456298828,
      "Geometry": {
        "BoundingBox": {
          "Height": 0.039078790694475174,
          "Left": 0.40573954582214355,
          "Top": 0.7455529570579529,
          "Width": 0.1779373735189438
        },
        "Polygon": [
          {
            "X": 0.40573954582214355,
            "Y": 0.7457388639450073
          },
          {
            "X": 0.5836592316627502,
            "Y": 0.7455529570579529
          },
          {
            "X": 0.5836769342422485,
            "Y": 0.7844481468200684
          },
          {
            "X": 0.405756413936615,
            "Y": 0.7846317887306213
          }
        ]
      },
      "Id": "d865002e-7c14-483d-a562-80f6507537e4",
      "Relationships": [
        {
          "Ids": [
            "82336828-a136-4e50-af22-ef394c673674"
          ],
          "Type": "CHILD"
        }
      ],
      "Text": "www.pv.com"
    },
    {
      "BlockType": "WORD",
      "Confidence": 91.37188720703125,
      "Geometry": {
        "BoundingBox": {
          "Height": 0.09335628896951675,
          "Left": 0.520653247833252,
          "Top": 0.20938247442245483,
          "Width": 0.27065518498420715
        },
        "Polygon": [
          {
            "X": 0.520653247833252,
            "Y": 0.2097129225730896
          },
          {
            "X": 0.791263997554779,
            "Y": 0.20938247442245483
          },
          {
            "X": 0.7913084626197815,
            "Y": 0.3024165630340576
          },
          {
            "X": 0.5206948518753052,
            "Y": 0.302738755941391
          }
        ]
      },
      "Id": "677c9b1b-40bb-45b0-b9db-336dba466820",
      "Text": "packetvideo",
      "TextType": "PRINTED"
    },
    {
      "BlockType": "WORD",
      "Confidence": 99.92396545410156,
      "Geometry": {
        "BoundingBox": {
          "Height": 0.

      "Geometry": {
        "BoundingBox": {
          "Height": 0.044862549751996994,
          "Left": 0.40632563829421997,
          "Top": 0.648216724395752,
          "Width": 0.11005442589521408
        },
        "Polygon": [
          {
            "X": 0.40632563829421997,
            "Y": 0.6483352184295654
          },
          {
            "X": 0.5163601040840149,
            "Y": 0.648216724395752
          },
          {
            "X": 0.5163800716400146,
            "Y": 0.6929623484611511
          },
          {
            "X": 0.40634503960609436,
            "Y": 0.6930792927742004
          }
        ]
      },
      "Id": "f0cdb575-9247-44d0-a6a8-493af9119788",
      "Text": "hoffman",
      "TextType": "PRINTED"
    },
    {
      "BlockType": "WORD",
      "Confidence": 98.9640121459961,
      "Geometry": {
        "BoundingBox": {
          "Height": 0.04362490400671959,
          "Left": 0.527627170085907,
          "Top": 0.6534423828125,
          "Width": 0.1052008643746376
        },
        "Polygon": [
          {
            "X": 0.527627170085907,
            "Y": 0.6535554528236389
          },
          {
            "X": 0.6328080296516418,
            "Y": 0.6534423828125
          },
          {
            "X": 0.6328279972076416,
            "Y": 0.696955680847168
          },
          {
            "X": 0.5276466608047485,
            "Y": 0.6970672607421875
          }
        ]
      },
      "Id": "85e1176e-8991-459e-bd41-aec88a842869",
      "Text": "estates,",
      "TextType": "PRINTED"
    },
    {
      "BlockType": "WORD",
      "Confidence": 98.50405883789062,
      "Geometry": {
        "BoundingBox": {
          "Height": 0.043249182403087616,
          "Left": 0.6448681950569153,
          "Top": 0.6482230424880981,
          "Width": 0.08140584081411362
        },
        "Polygon": [
          {
            "X": 0.6448681950569153,
            "Y": 0.648310661315918
          },
          {
            "X": 0.7262537479400635,
            "Y": 0.6482230424880981
          },
          {
            "X": 0.7262740135192871,
            "Y": 0.6913857460021973
          },
          {
            "X": 0.6448881030082703,
            "Y": 0.6914722323417664
          }
        ]
      },
      "Id": "d3e4e845-da0c-4cc8-a346-49057e274597",
      "Text": "illinois",
      "TextType": "PRINTED"
    },
    {
      "BlockType": "WORD",
      "Confidence": 99.953857421875,
      "Geometry": {
        "BoundingBox": {
          "Height": 0.0393308587372303,
          "Left": 0.7363747954368591,
          "Top": 0.6514960527420044,
          "Width": 0.07341588288545609
        },
        "Polygon": [
          {
            "X": 0.7363747954368591,
            "Y": 0.6515750288963318
          },
          {
            "X": 0.8097718954086304,
            "Y": 0.6514960527420044
          },
          {
            "X": 0.8097907304763794,
            "Y": 0.6907488703727722
          },
          {
            "X": 0.7363933324813843,
            "Y": 0.6908268928527832
          }
        ]
      },
      "Id": "f0500e1d-e5c2-48f2-82fd-7c28f3e16dd5",
      "Text": "60192",
      "TextType": "PRINTED"
    },
    {
      "BlockType": "WORD",
      "Confidence": 99.28849792480469,
      "Geometry": {
        "BoundingBox": {
          "Height": 0.051345229148864746,
          "Left": 0.1019669622182846,
          "Top": 0.742109477519989,
          "Width": 0.22008559107780457
        },
        "Polygon": [
          {
            "X": 0.1019669622182846,
            "Y": 0.7423397302627563
          },
          {
            "X": 0.3220308721065521,
            "Y": 0.742109477519989
          },
          {
            "X": 0.32205256819725037,
            "Y": 0.7932281494140625
          },
          {
            "X": 0.10198737680912018,
            "Y": 0.7934547066688538
          }
        ]
      },
      "Id": "7b43f5ee-716b-4c74-a7d7-d6e4fe40a7aa",
      "Text": "svienty@pv.com",
      "TextType": "PRINTED"
    },
    {
      "BlockType": "WORD",
      "Confidence": 99.37836456298828,
      "Geometry": {
        "BoundingBox": {
          "Height": 0.039078790694475174,
          "Left": 0.40573954582214355,
          "Top": 0.7455529570579529,
          "Width": 0.1779373735189438
        },
        "Polygon": [
          {
            "X": 0.40573954582214355,
            "Y": 0.7457388639450073
          },
          {
            "X": 0.5836592316627502,
            "Y": 0.7455529570579529
          },
          {
            "X": 0.5836769342422485,
            "Y": 0.7844481468200684
          },
          {
            "X": 0.405756413936615,
            "Y": 0.7846317887306213
          }
        ]
      },
      "Id": "82336828-a136-4e50-af22-ef394c673674",
      "Text": "www.pv.com",
      "TextType": "PRINTED"
    },
    {
      "BlockType": "KEY_VALUE_SET",
      "Confidence": 55.05661392211914,
      "EntityTypes": [
        "KEY"
      ],
      "Geometry": {
        "BoundingBox": {
          "Height": 0.05328961834311485,
          "Left": 0.09353452175855637,
          "Top": 0.4243454039096832,
          "Width": 0.23332670331001282
        },
        "Polygon": [
          {
            "X": 0.09353452175855637,
            "Y": 0.4246138632297516
          },
          {
            "X": 0.3268387019634247,
            "Y": 0.4243454039096832
          },
          {
            "X": 0.3268612325191498,
            "Y": 0.47737064957618713
          },
          {
            "X": 0.09355564415454865,
            "Y": 0.4776350259780884
          }
        ]
      },
      "Id": "82cd4db8-c54f-47cf-8d97-258aedc9e376",
      "Relationships": [
        {
          "Ids": [
            "e7f8857d-277c-45ee-8821-daf81f6ec9eb"
          ],
          "Type": "VALUE"
        },
        {
          "Ids": [
            "84b72814-52bf-4e8c-992d-f410ee599760",
            "9ed4a9c7-d1bf-43ad-8e6e-5931b62a83e6"
          ],
          "Type": "CHILD"
        }
      ]
    },
    {
      "BlockType": "KEY_VALUE_SET",
      "Confidence": 55.05661392211914,
      "EntityTypes": [
        "VALUE"
      ],
      "Geometry": {
        "BoundingBox": {
          "Height": 0.20545102655887604,
          "Left": 0.09650265425443649,
          "Top": 0.5890479683876038,
          "Width": 0.2283404916524887
        },
        "Polygon": [
          {
            "X": 0.09650265425443649,
            "Y": 0.5892982482910156
          },
          {
            "X": 0.324755996465683,
            "Y": 0.5890479683876038
          },
          {
            "X": 0.3248431384563446,
            "Y": 0.7942641377449036
          },
          {
            "X": 0.09658446907997131,
            "Y": 0.7944989800453186
          }
        ]
      },
      "Id": "e7f8857d-277c-45ee-8821-daf81f6ec9eb",
      "Relationships": [
        {
          "Ids": [
            "7c1b5aa9-84b2-45aa-8d62-59eb2dee94f4",
            "44b8f01f-787a-48b5-bb6d-2a16031478e3",
            "b63d0f59-45ce-499b-96a1-f0142d06c781",
            "9a721637-479d-4afb-84f0-6aeab0c34dcd",
            "9b09f79d-38d1-42d0-9fa3-ae585adba2a6",
            "b580d9a5-ba66-4c84-ab06-d37171ddf7b2",
            "7b43f5ee-716b-4c74-a7d7-d6e4fe40a7aa"
          ],
          "Type": "CHILD"
        }
      ]
    },
    {
      "BlockType": "KEY_VALUE_SET",
      "Confidence": 43.79147720336914,
      "EntityTypes": [
        "KEY"
      ],
      "Geometry": {
        "BoundingBox": {
          "Height": 0.048298537731170654,
          "Left": 0.40537965297698975,
          "Top": 0.43393006920814514,
          "Width": 0.33561989665031433
        },
        "Polygon": [
          {
            "X": 0.40537965297698975,
            "Y": 0.43431511521339417
          },
          {
            "X": 0.7409769296646118,
            "Y": 0.43393006920814514
          },
          {
            "X": 0.7409995198249817,
            "Y": 0.4818488359451294
          },
          {
            "X": 0.40540042519569397,
            "Y": 0.4822286069393158
          }
        ]
      },
      "Id": "ec063eb9-52d7-47a6-960d-0a17679d0fd3",
      "Relationships": [
        {
          "Ids": [
            "f2b1779f-41d2-4b01-b527-15306a9e59d8"
          ],
          "Type": "VALUE"
        },
        {
          "Ids": [
            "c4035733-a08a-453b-a899-d24bf6747da0",
            "e606e718-6665-498e-b1a9-a17823034bd6",
            "de68b1a6-e69a-4e5a-9162-09a057395d39",
            "fc80ffde-a8c0-455f-b4c7-a858aba439be"
          ],
          "Type": "CHILD"
        }
      ]
    },
    {
      "BlockType": "KEY_VALUE_SET",
      "Confidence": 43.79147720336914,
      "EntityTypes": [
        "VALUE"
      ],
      "Geometry": {
        "BoundingBox": {
          "Height": 0.21046440303325653,
          "Left": 0.4060070812702179,
          "Top": 0.5759744644165039,
          "Width": 0.41055333614349365
        },
        "Polygon": [
          {
            "X": 0.4060070812702179,
            "Y": 0.5764262080192566
          },
          {
            "X": 0.8164594769477844,
            "Y": 0.5759744644165039
          },
          {
            "X": 0.8165603876113892,
            "Y": 0.7860153913497925
          },
          {
            "X": 0.4060981869697571,
            "Y": 0.7864388227462769
          }
        ]
      },
      "Id": "f2b1779f-41d2-4b01-b527-15306a9e59d8",
      "Relationships": [
        {
          "Ids": [
            "63b3da42-7970-4e86-8d8e-83c3dd6b8094",
            "8398f455-e6a3-4a21-82b1-23416684a440",
            "aec0617e-cc4b-4788-9ea1-8ed28136eb0f",
            "35541ae1-73b5-4f63-91af-69571dd7f644",
            "1fa21968-c44d-4040-8c8d-b27e78acc988",
            "f0cdb575-9247-44d0-a6a8-493af9119788",
            "85e1176e-8991-459e-bd41-aec88a842869",
            "d3e4e845-da0c-4cc8-a346-49057e274597",
            "f0500e1d-e5c2-48f2-82fd-7c28f3e16dd5",
            "82336828-a136-4e50-af22-ef394c673674"
          ],
          "Type": "CHILD"
        }
      ]
    }
  ],
  "DocumentMetadata": {
    "Pages": 1
  }
}

# %%
for block in sample_res.get("Blocks"):
    if block.get("BlockType") == "LINE":
        print(block.get("BlockType"))
        print(block.get("Text"))
# Out:
# LINE
# packetvideo
# LINE
# Richard Svienty
# LINE
# member of technical staff
# LINE
# t 847 273-5617
# LINE
# 5407 trillium boulevard, suite 130
# LINE
# f 847 273-5610
# LINE
# hoffman estates, illinois 60192
# LINE
# svienty@pv.com
# LINE
# www.pv.com

# %%
lst = []
lst
# Out:
# []

# %%
lst.append([block.get("Text") for block in sample_res.get("Blocks") if block.get("BlockType") == "LINE"])
lst
# Out:
# [['packetvideo',
#   'Richard Svienty',
#   'member of technical staff',
#   't 847 273-5617',
#   '5407 trillium boulevard, suite 130',
#   'f 847 273-5610',
#   'hoffman estates, illinois 60192',
#   'svienty@pv.com',
#   'www.pv.com']]

# %%
a = []
b = 1
c = [1, 2]

# %%
a.append(b)
a.append(c)
a
# Out:
# [1, [1, 2]]

# %%
a.append(b)
a.extend(c)
a
# Out:
# [1, 1, 2]

# %%
response = {
  "Entities": [
    {
      "BeginOffset": 12,
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "EndOffset": 27,
      "Id": 1,
      "Score": 0.9874351024627686,
      "Text": "Richard Svienty",
      "Traits": [
        
      ],
      "Type": "NAME"
    },
    {
      "BeginOffset": 54,
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "EndOffset": 55,
      "Id": 2,
      "Score": 0.2965961694717407,
      "Text": "t",
      "Traits": [
        
      ],
      "Type": "NAME"
    },
    {
      "BeginOffset": 56,
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "EndOffset": 68,
      "Id": 3,
      "Score": 0.9990946054458618,
      "Text": "847 273-5617",
      "Traits": [
        
      ],
      "Type": "PHONE_OR_FAX"
    },
    {
      "BeginOffset": 69,
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "EndOffset": 103,
      "Id": 4,
      "Score": 0.957107424736023,
      "Text": "5407 trillium boulevard, suite 130",
      "Traits": [
        
      ],
      "Type": "ADDRESS"
    },
    {
      "BeginOffset": 106,
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "EndOffset": 118,
      "Id": 5,
      "Score": 0.9986748695373535,
      "Text": "847 273-5610",
      "Traits": [
        
      ],
      "Type": "PHONE_OR_FAX"
    },
    {
      "BeginOffset": 119,
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "EndOffset": 150,
      "Id": 6,
      "Score": 0.7562633752822876,
      "Text": "hoffman estates, illinois 60192",
      "Traits": [
        
      ],
      "Type": "ADDRESS"
    },
    {
      "BeginOffset": 151,
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "EndOffset": 165,
      "Id": 7,
      "Score": 0.9973135590553284,
      "Text": "svienty@pv.com",
      "Traits": [
        
      ],
      "Type": "EMAIL"
    },
    {
      "BeginOffset": 166,
      "Category": "PROTECTED_HEALTH_INFORMATION",
      "EndOffset": 176,
      "Id": 8,
      "Score": 0.9946327209472656,
      "Text": "www.pv.com",
      "Traits": [
        
      ],
      "Type": "URL"
    }
  ],
  "ModelVersion": "2.3.0",
  "UnmappedAttributes": [
    
  ]
}

# %%
for entity in response.get("Entities"):
    print(entity.get("Text"))
    print(entity.get("Score"))
    print(entity.get("Type"))
# Out:
# Richard Svienty
# 0.9874351024627686
# NAME
# t
# 0.2965961694717407
# NAME
# 847 273-5617
# 0.9990946054458618
# PHONE_OR_FAX
# 5407 trillium boulevard, suite 130
# 0.957107424736023
# ADDRESS
# 847 273-5610
# 0.9986748695373535
# PHONE_OR_FAX
# hoffman estates, illinois 60192
# 0.7562633752822876
# ADDRESS
# svienty@pv.com
# 0.9973135590553284
# EMAIL
# www.pv.com
# 0.9946327209472656
# URL

# %%
[{"Text":entity.get("Text"), "Type":entity.get("Type"), "Score": round(entity.get("Score"), 2)} for entity in response.get("Entities")]
# Out:
# [{'Text': 'Richard Svienty', 'Type': 'NAME', 'Score': 0.99},
#  {'Text': 't', 'Type': 'NAME', 'Score': 0.3},
#  {'Text': '847 273-5617', 'Type': 'PHONE_OR_FAX', 'Score': 1.0},
#  {'Text': '5407 trillium boulevard, suite 130',
#   'Type': 'ADDRESS',
#   'Score': 0.96},
#  {'Text': '847 273-5610', 'Type': 'PHONE_OR_FAX', 'Score': 1.0},
#  {'Text': 'hoffman estates, illinois 60192', 'Type': 'ADDRESS', 'Score': 0.76},
#  {'Text': 'svienty@pv.com', 'Type': 'EMAIL', 'Score': 1.0},
#  {'Text': 'www.pv.com', 'Type': 'URL', 'Score': 0.99}]
